# %%
# i) String
my_string = "Hello, Jupyter Notebook!"

# ii) List
my_list = [1, 2, 3, 4, 5]

# iii) Float
my_float = 3.14

# iv) Tuple
my_tuple = (10, 20, 30)

my_string, my_list, my_float, my_tuple
# Out:
# ('Hello, Jupyter Notebook!', [1, 2, 3, 4, 5], 3.14, (10, 20, 30))
