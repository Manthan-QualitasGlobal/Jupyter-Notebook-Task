# %%
# Division operator (/)
a = 10
b = 4
print("Division (/):", a / b)

# Modulus operator (%)
print("Modulus (%):", a % b)

# Floor division operator (//)
print("Floor Division (//):", a // b)

# Exponentiation operator (**)
x = 2
y = 3
print("Exponentiation (**):", x ** y)
# Out:
# Division (/): 2.5
# Modulus (%): 2
# Floor Division (//): 2
# Exponentiation (**): 8
